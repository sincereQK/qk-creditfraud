# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib import gridspec

# %%
data = pd.read_csv("../input/creditcardfraud/creditcard.csv")

# %%
data.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
print(data.shape) 
print(data.describe())
# Out:
# (284807, 31)
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
fraud = data[data['Class'] == 1] 
valid = data[data['Class'] == 0] 
outlierFraction = len(fraud)/float(len(valid)) 
print(outlierFraction) 
print('Fraud Cases: {}'.format(len(data[data['Class'] == 1]))) 
print('Valid Transactions: {}'.format(len(data[data['Class'] == 0])))
# Out:
# 0.0017304750013189597
# Fraud Cases: 492
# Valid Transactions: 284315

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
valid.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
#상관행렬 출력
corrmat = data.corr() 
fig = plt.figure(figsize = (12, 9)) 
sns.heatmap(corrmat, vmax = .8, square = True) 
plt.show()

# %%
X = data.drop(['Class'], axis = 1) 
Y = data["Class"] 
print(X.shape) 
print(Y.shape) 
xData = X.values 
yData = Y.values
# Out:
# (284807, 30)
# (284807,)

# %% [markdown]
# # **RandomForest**

# %%
#train test 분리
from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(xData, yData, test_size = 0.2)
#xTrain, xTest, yTrain, yTest = train_test_split(xData, yData, test_size = 0.1)

# %%
from sklearn.ensemble import RandomForestClassifier 
rfc = RandomForestClassifier() 
rfc.fit(xTrain, yTrain) 
yPred = rfc.predict(xTest)

# %%
#building all kinds of evaluating parameters
from sklearn.metrics import classification_report, accuracy_score  
from sklearn.metrics import precision_score, recall_score 
from sklearn.metrics import f1_score, matthews_corrcoef 
from sklearn.metrics import confusion_matrix 
  
n_outliers = len(fraud) 
n_errors = (yPred != yTest).sum() 
print("The model used is Random Forest classifier") 
  
acc = accuracy_score(yTest, yPred) 
print("The accuracy is {}".format(acc)) 
  
prec = precision_score(yTest, yPred) 
print("The precision is {}".format(prec)) 
  
rec = recall_score(yTest, yPred) 
print("The recall is {}".format(rec)) 
  
f1 = f1_score(yTest, yPred) 
print("The F1-Score is {}".format(f1)) 
  
MCC = matthews_corrcoef(yTest, yPred) 
print("The Matthews correlation coefficient is{}".format(MCC))
# Out:
# The model used is Random Forest classifier
# The accuracy is 0.9996664442961974
# The precision is 0.9886363636363636
# The recall is 0.8285714285714286
# The F1-Score is 0.9015544041450777
# The Matthews correlation coefficient is0.9049178016768907

# %%
#visulalizing the confusion matrix
LABELS = ['Normal', 'Fraud'] 
conf_matrix = confusion_matrix(yTest, yPred) 
plt.figure(figsize =(12, 12)) 
sns.heatmap(conf_matrix, xticklabels = LABELS, yticklabels = LABELS, annot = True, fmt ="d"); 
plt.title("Confusion matrix") 
plt.ylabel('True class') 
plt.xlabel('Predicted class') 
plt.show()

# %% [markdown]
# # **XGBoost**

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics

from sklearn.metrics import accuracy_score,roc_auc_score,precision_score, recall_score,f1_score,classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(xData, yData,test_size = 0.2)
#X_train, X_test, y_train, y_test = train_test_split(xData, yData,test_size = 0.1)

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# %%
print("The model used is XGBoost") 

accuracy = accuracy_score(y_test, predictions)
#print("Accuracy: %.2f%%" % (accuracy * 100.0))
print("The accuracy is {}".format(accuracy))

precision = precision_score(y_test, predictions)
#print("Precision : %.2f%%" % (precision * 100.0))
print("The precision is {}".format(precision))

recall = recall_score(y_test, y_pred)
#print("Recall : ",recall )
print("The recall is {}".format(recall))

f1score = f1_score(y_test,y_pred, average='macro')
#print("F1 Score : ",f1score )
print("The F1-Score is {}".format(f1score))

MCC = matthews_corrcoef(y_test, y_pred) 
print("The Matthews correlation coefficient is {}".format(MCC))
# Out:
# The model used is XGBoost
# The accuracy is 0.9996488887328394
# The precision is 0.9777777777777777
# The recall is 0.8301886792452831
# The F1-Score is 0.9488916627427562
# The Matthews correlation coefficient is 0.9008012562632363

# %%
c_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
fig, (ax1) = plt.subplots(ncols=1, figsize=(5,5))

sns.heatmap(pd.DataFrame(c_matrix), annot=True, cmap="Reds" ,fmt='g',
            xticklabels=['Not Fraud', 'Fraud'],
            yticklabels=['Not Fraud', 'Fraud'],)
ax1.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion Matrix', y=1.1,fontsize=14)
plt.show()

# %% [markdown]
# # **lightgbm**

# %%
#X_train, X_test, y_train, y_test = train_test_split(xData, yData,test_size = 0.1, random_state=156)
#xTrain, xTest, yTrain, yTest = train_test_split(xData, yData, test_size = 0.1)

Xtrain, Xtest, Ytrain, Ytest=train_test_split(xData, yData, test_size=0.2)
#Xtrain, Xtest, Ytrain, Ytest=train_test_split(xData, yData, test_size=0.1)

# %%
from lightgbm import LGBMClassifier

lgbm_wrapper = LGBMClassifier(n_estimators=400)

evals = [(Xtest, Ytest)] # 원래는 이렇게 하면 과적합
lgbm_wrapper.fit(Xtrain, Ytrain, early_stopping_rounds=100, eval_metric="logloss", eval_set=evals, verbose=True)

preds = lgbm_wrapper.predict(Xtest)
pred_proba = lgbm_wrapper.predict_proba(Xtest)[:, 1]
# Out:
# [1]	valid_0's binary_logloss: 0.0124719
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's binary_logloss: 0.0259973
# [3]	valid_0's binary_logloss: 0.0213131
# [4]	valid_0's binary_logloss: 0.0243788
# [5]	valid_0's binary_logloss: 0.0234304
# [6]	valid_0's binary_logloss: 0.0289848
# [7]	valid_0's binary_logloss: 0.025444
# [8]	valid_0's binary_logloss: 0.0264375
# [9]	valid_0's binary_logloss: 0.0255963
# [10]	valid_0's binary_logloss: 0.0243662
# [11]	valid_0's binary_logloss: 0.0262521
# [12]	valid_0's binary_logloss: 0.0272232
# [13]	valid_0's binary_logloss: 0.0294735
# [14]	valid_0's binary_logloss: 0.0289691
# [15]	valid_0's binary_logloss: 0.0359529
# [16]	valid_0's binary_logloss: 0.0342217
# [17]	valid_0's binary_logloss: 0.0410832
# [18]	valid_0's binary_logloss: 0.0398759
# [19]	valid_0's binary_logloss: 0.0415778
# [20]	valid_0's binary_logloss: 0.0411024
# [21]	valid_0's binary_logloss: 0.0451079
# [22]	valid_0's binary_logloss: 0.0414447
# [23]	valid_0's binary_logloss: 0.0494606
# [24]	valid_0's binary_logloss: 0.0460331
# [25]	valid_0's binary_logloss: 0.0581767
# [26]	valid_0's binary_logloss: 0.052768
# [27]	valid_0's binary_logloss: 0.0660351
# [28]	valid_0's binary_logloss: 0.057155
# [29]	valid_0's binary_logloss: 0.0831468
# [30]	valid_0's binary_logloss: 0.0696452
# [31]	valid_0's binary_logloss: 0.0691233
# [32]	valid_0's binary_logloss: 0.0649086
# [33]	valid_0's binary_logloss: 0.0668025
# [34]	valid_0's binary_logloss: 0.092198
# [35]	valid_0's binary_logloss: 0.0794819
# [36]	valid_0's binary_logloss: 0.0875948
# [37]	valid_0's binary_logloss: 0.101611
# [38]	valid_0's binary_logloss: 0.104588
# [39]	valid_0's binary_logloss: 0.153075
# [40]	valid_0's binary_logloss: 0.136442
# [41]	valid_0's binary_logloss: 0.17536
# [42]	valid_0's binary_logloss: 0.259257
# [43]	valid_0's binary_logloss: 0.125725
# [44]	valid_0's binary_logloss: 0.247416
# [45]	valid_0's binary_logloss: 0.0908337
# [46]	valid_0's binary_logloss: 0.0708573
# [47]	valid_0's binary_logloss: 0.071905
# [48]	valid_0's binary_logloss: 0.113266
# [49]	valid_0's binary_logloss: 0.124547
# [50]	valid_0's binary_logloss: 0.132587
# [51]	valid_0's binary_logloss: 0.162475
# [52]	valid_0's binary_logloss: 0.0776085
# [53]	valid_0's binary_logloss: 0.107437
# [54]	valid_0's binary_logloss: 0.295722
# [55]	valid_0's binary_logloss: 0.0959509
# [56]	valid_0's binary_logloss: 0.617658
# [57]	valid_0's binary_logloss: 0.0784659
# [58]	valid_0's binary_logloss: 1.02092
# [59]	valid_0's binary_logloss: 0.574212
# [60]	valid_0's binary_logloss: 0.0686696
# [61]	valid_0's binary_logloss: 0.158333
# [62]	valid_0's binary_logloss: 0.300697
# [63]	valid_0's binary_logloss: 0.130852
# [64]	valid_0's binary_logloss: 0.256854
# [65]	valid_0's binary_logloss: 0.374978
# [66]	valid_0's binary_logloss: 0.0742085
# [67]	valid_0's binary_logloss: 0.180649
# [68]	valid_0's binary_logloss: 0.114447
# [69]	valid_0's binary_logloss: 0.131437
# [70]	valid_0's binary_logloss: 0.0761684
# [71]	valid_0's binary_logloss: 0.247463
# [72]	valid_0's binary_logloss: 0.12047
# [73]	valid_0's binary_logloss: 0.154629
# [74]	valid_0's binary_logloss: 0.122649
# [75]	valid_0's binary_logloss: 0.365999
# [76]	valid_0's binary_logloss: 0.249994
# [77]	valid_0's binary_logloss: 0.245287
# [78]	valid_0's binary_logloss: 0.106846
# [79]	valid_0's binary_logloss: 0.830358
# [80]	valid_0's binary_logloss: 0.126411
# [81]	valid_0's binary_logloss: 0.212928
# [82]	valid_0's binary_logloss: 0.257614
# [83]	valid_0's binary_logloss: 0.426256
# [84]	valid_0's binary_logloss: 0.100139
# [85]	valid_0's binary_logloss: 0.352789
# [86]	valid_0's binary_logloss: 0.391979
# [87]	valid_0's binary_logloss: 0.128788
# [88]	valid_0's binary_logloss: 0.18116
# [89]	valid_0's binary_logloss: 0.337529
# [90]	valid_0's binary_logloss: 0.313456
# [91]	valid_0's binary_logloss: 0.134949
# [92]	valid_0's binary_logloss: 0.190354
# [93]	valid_0's binary_logloss: 0.310454
# [94]	valid_0's binary_logloss: 0.15829
# [95]	valid_0's binary_logloss: 0.137562
# [96]	valid_0's binary_logloss: 0.28933
# [97]	valid_0's binary_logloss: 0.266361
# [98]	valid_0's binary_logloss: 0.732795
# [99]	valid_0's binary_logloss: 0.281427
# [100]	valid_0's binary_logloss: 0.238638
# [101]	valid_0's binary_logloss: 0.20822
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0124719

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

confusion = confusion_matrix(Ytest, preds)
accuracy = accuracy_score(Ytest, preds)
precision = precision_score(Ytest, preds)
recall = recall_score(Ytest, preds)
f1 = f1_score(Ytest, preds)
roc_auc = roc_auc_score(Ytest, pred_proba)

print(confusion)
print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))
# Out:
# [[56824    38]
#  [   14    86]]
# 정확도: 0.9991, 정밀도: 0.6935, 재현율: 0.8600, F1: 0.7679, AUC:0.9277

# %%
print("The model used is lightgbm")

accuracy = accuracy_score(Ytest, preds)
#print("Accuracy: %.2f%%" % (accuracy * 100.0))
print("The accuracy is {}".format(accuracy))

precision = precision_score(Ytest, preds)
#print("Precision : %.2f%%" % (precision * 100.0))
print("The precision is {}".format(precision))

recall = recall_score(Ytest, preds)
#print("Recall : ",recall )
print("The recall is {}".format(recall))

f1score = f1_score(Ytest, preds, average='macro')
#print("F1 Score : ",f1score )
print("The F1-Score is {}".format(f1score))

MCC = matthews_corrcoef(Ytest, preds) 
print("The Matthews correlation coefficient is {}".format(MCC))
# Out:
# The model used is lightgbm
# The accuracy is 0.9990871107053826
# The precision is 0.6935483870967742
# The recall is 0.86
# The F1-Score is 0.8836998994848599
# The Matthews correlation coefficient is 0.7718655709888369

# %%
c_matrix = pd.crosstab(Ytest, preds, rownames=['Actual'], colnames=['Predicted'])
fig, (ax1) = plt.subplots(ncols=1, figsize=(5,5))

sns.heatmap(pd.DataFrame(c_matrix), annot=True, cmap="Reds" ,fmt='g',
            xticklabels=['Not Fraud', 'Fraud'],
            yticklabels=['Not Fraud', 'Fraud'],)
ax1.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion Matrix', y=1.1,fontsize=14)
plt.show()
